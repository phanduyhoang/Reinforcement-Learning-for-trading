# %%
# !pip install stable-baselines3[extra]

# %%
# !apt-get install swig
# !pip install gymnasium
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   swig4.0
# Suggested packages:
#   swig-doc swig-examples swig4.0-examples swig4.0-doc
# The following NEW packages will be installed:
#   swig swig4.0
# 0 upgraded, 2 newly installed, 0 to remove and 49 not upgraded.
# Need to get 1,116 kB of archives.
# After this operation, 5,542 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 swig4.0 amd64 4.0.2-1ubuntu1 [1,110 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 swig all 4.0.2-1ubuntu1 [5,632 B]
# Fetched 1,116 kB in 1s (1,006 kB/s)
# Selecting previously unselected package swig4.0.
# (Reading database ... 124565 files and directories currently installed.)
# Preparing to unpack .../swig4.0_4.0.2-1ubuntu1_amd64.deb ...
# Unpacking swig4.0 (4.0.2-1ubuntu1) ...
# Selecting previously unselected package swig.
# Preparing to unpack .../swig_4.0.2-1ubuntu1_all.deb ...
# Unpacking swig (4.0.2-1ubuntu1) ...
# Setting up swig4.0 (4.0.2-1ubuntu1) ...
# Setting up swig (4.0.2-1ubuntu1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.11/dist-packages (1.0.0)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (3.1.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (0.0.4)

# %%
# !pip install gym-anytrading
# Out:
# Collecting gym-anytrading
#   Using cached gym_anytrading-2.0.0-py3-none-any.whl.metadata (292 bytes)
# Requirement already satisfied: gymnasium>=0.29.1 in /usr/local/lib/python3.11/dist-packages (from gym-anytrading) (1.0.0)
# Requirement already satisfied: numpy>=1.16.4 in /usr/local/lib/python3.11/dist-packages (from gym-anytrading) (1.26.4)
# Requirement already satisfied: pandas>=0.24.2 in /usr/local/lib/python3.11/dist-packages (from gym-anytrading) (2.2.2)
# Requirement already satisfied: matplotlib>=3.1.1 in /usr/local/lib/python3.11/dist-packages (from gym-anytrading) (3.10.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium>=0.29.1->gym-anytrading) (3.1.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium>=0.29.1->gym-anytrading) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium>=0.29.1->gym-anytrading) (0.0.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.1.1->gym-anytrading) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.1.1->gym-anytrading) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.1.1->gym-anytrading) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.1.1->gym-anytrading) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.1.1->gym-anytrading) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.1.1->gym-anytrading) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.1.1->gym-anytrading) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.1.1->gym-anytrading) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24.2->gym-anytrading) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24.2->gym-anytrading) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.1.1->gym-anytrading) (1.17.0)
# Downloading gym_anytrading-2.0.0-py3-none-any.whl (172 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.2/172.2 kB 3.8 MB/s eta 0:00:00
# Installing collected packages: gym-anytrading
# Successfully installed gym-anytrading-2.0.0

# %%
import gymnasium as gym
import gym_anytrading
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3 import A2C

import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
df=pd.read_csv('/content/gmedata.csv')
df.head()
# Out:
#          Date    Open    High     Low  Close      Volume
# 0  03/12/2021  275.00  295.50  262.27  264.5  25,845,900
# 1  03/11/2021  241.64  281.50  232.60  260.0  28,312,490
# 2  03/10/2021  269.43  348.50  172.00  265.0  71,570,570
# 3  03/09/2021  217.71  249.85  208.51  246.9  39,099,328
# 4  03/08/2021  154.89  210.87  146.10  194.5  63,565,621

# %%
df['Date']=pd.to_datetime(df['Date'])
df.dtypes
# Out:
# Date      datetime64[ns]
# Open             float64
# High             float64
# Low              float64
# Close            float64
# Volume            object
# dtype: object

# %%
df.set_index("Date", inplace=True)
df.head()
# Out:
#               Open    High     Low  Close      Volume
# Date
# 2021-03-12  275.00  295.50  262.27  264.5  25,845,900
# 2021-03-11  241.64  281.50  232.60  260.0  28,312,490
# 2021-03-10  269.43  348.50  172.00  265.0  71,570,570
# 2021-03-09  217.71  249.85  208.51  246.9  39,099,328
# 2021-03-08  154.89  210.87  146.10  194.5  63,565,621

# %%
env=gym.make('stocks-v0',df=df, frame_bound=(10,100), window_size=5)

# %%
base_env = env.unwrapped
print(base_env.signal_features)
# Out:
# [[ 1.3774e+02  0.0000e+00]
#  [ 1.3235e+02 -5.3900e+00]
#  [ 1.2418e+02 -8.1700e+00]
#  [ 1.1818e+02 -6.0000e+00]
#  [ 1.2040e+02  2.2200e+00]
#  [ 1.0174e+02 -1.8660e+01]
#  [ 1.0873e+02  6.9900e+00]
#  [ 9.1710e+01 -1.7020e+01]
#  [ 4.4970e+01 -4.6740e+01]
#  [ 4.6000e+01  1.0300e+00]
#  [ 4.0590e+01 -5.4100e+00]
#  [ 4.0690e+01  1.0000e-01]
#  [ 4.5940e+01  5.2500e+00]
#  [ 4.9510e+01  3.5700e+00]
#  [ 5.2400e+01  2.8900e+00]
#  [ 5.1100e+01 -1.3000e+00]
#  [ 5.1200e+01  1.0000e-01]
#  [ 5.0310e+01 -8.9000e-01]
#  [ 6.0000e+01  9.6900e+00]
#  [ 6.3770e+01  3.7700e+00]
#  [ 5.3500e+01 -1.0270e+01]
#  [ 9.2410e+01  3.8910e+01]
#  [ 9.0000e+01 -2.4100e+00]
#  [ 2.2500e+02  1.3500e+02]
#  [ 3.2500e+02  1.0000e+02]
#  [ 1.9360e+02 -1.3140e+02]
#  [ 3.4751e+02  1.5391e+02]
#  [ 1.4798e+02 -1.9953e+02]
#  [ 7.6790e+01 -7.1190e+01]
#  [ 6.5010e+01 -1.1780e+01]
#  [ 4.3030e+01 -2.1980e+01]
#  [ 3.9120e+01 -3.9100e+00]
#  [ 3.9360e+01  2.4000e-01]
#  [ 3.5500e+01 -3.8600e+00]
#  [ 3.9910e+01  4.4100e+00]
#  [ 3.1400e+01 -8.5100e+00]
#  [ 1.9950e+01 -1.1450e+01]
#  [ 1.9940e+01 -1.0000e-02]
#  [ 1.7690e+01 -2.2500e+00]
#  [ 1.8080e+01  3.9000e-01]
#  [ 1.8360e+01  2.8000e-01]
#  [ 1.7370e+01 -9.9000e-01]
#  [ 1.7250e+01 -1.2000e-01]
#  [ 1.8840e+01  1.5900e+00]
#  [ 1.9260e+01  4.2000e-01]
#  [ 1.9380e+01  1.2000e-01]
#  [ 2.0990e+01  1.6100e+00]
#  [ 2.0150e+01 -8.4000e-01]
#  [ 2.0570e+01  4.2000e-01]
#  [ 1.9460e+01 -1.1100e+00]
#  [ 1.5530e+01 -3.9300e+00]
#  [ 1.5630e+01  1.0000e-01]
#  [ 1.4830e+01 -8.0000e-01]
#  [ 1.3850e+01 -9.8000e-01]
#  [ 1.3850e+01  0.0000e+00]
#  [ 1.2720e+01 -1.1300e+00]
#  [ 1.3310e+01  5.9000e-01]
#  [ 1.4120e+01  8.1000e-01]
#  [ 1.3660e+01 -4.6000e-01]
#  [ 1.6940e+01  3.2800e+00]
#  [ 1.6350e+01 -5.9000e-01]
#  [ 1.6900e+01  5.5000e-01]
#  [ 1.6120e+01 -7.8000e-01]
#  [ 1.6580e+01  4.6000e-01]
#  [ 1.5800e+01 -7.8000e-01]
#  [ 1.6560e+01  7.6000e-01]
#  [ 1.6080e+01 -4.8000e-01]
#  [ 1.4750e+01 -1.3300e+00]
#  [ 1.3670e+01 -1.0800e+00]
#  [ 1.3900e+01  2.3000e-01]
#  [ 1.2710e+01 -1.1900e+00]
#  [ 1.2460e+01 -2.5000e-01]
#  [ 1.1570e+01 -8.9000e-01]
#  [ 1.1630e+01  6.0000e-02]
#  [ 1.2060e+01  4.3000e-01]
#  [ 1.1010e+01 -1.0500e+00]
#  [ 1.1130e+01  1.2000e-01]
#  [ 1.1750e+01  6.2000e-01]
#  [ 1.1100e+01 -6.5000e-01]
#  [ 1.1490e+01  3.9000e-01]
#  [ 1.1860e+01  3.7000e-01]
#  [ 1.1450e+01 -4.1000e-01]
#  [ 1.0910e+01 -5.4000e-01]
#  [ 1.1570e+01  6.6000e-01]
#  [ 1.0750e+01 -8.2000e-01]
#  [ 1.0470e+01 -2.8000e-01]
#  [ 1.1730e+01  1.2600e+00]
#  [ 1.1820e+01  9.0000e-02]
#  [ 1.2690e+01  8.7000e-01]
#  [ 1.3450e+01  7.6000e-01]
#  [ 1.5000e+01  1.5500e+00]
#  [ 1.4910e+01 -9.0000e-02]
#  [ 1.4100e+01 -8.1000e-01]
#  [ 1.3860e+01 -2.4000e-01]
#  [ 1.3910e+01  5.0000e-02]]

# %%
# Create the environment
env = gym.make('stocks-v0', df=df, frame_bound=(10, 90), window_size=5)

# Reset the environment
state = env.reset()

while True:
    action = env.action_space.sample()
    n_state, reward, done, info,_= env.step(action)
    if done:
        print("info", info)
        break

# Render the environment
plt.figure(figsize=(15, 6))
plt.cla()
env.render_all()
plt.show()

# %%
env_maker=lambda:gym.make('stocks-v0', df=df,frame_bound=(5,100), window_size=5)

env=DummyVecEnv([env_maker])

model=A2C('MlpLstmPolicy', env, verbose=1)
model.learn(total_timesteps=100000)

# %%
env = gym.make('stocks-v0', df=df, frame_bound=(90,110), window_size=5)
obs = env.reset()
while True:
    obs = obs[np.newaxis, ...]
    action, _states = model.predict(obs)
    obs, rewards, done, info = env.step(action)
    if done:
        print("info", info)
        break

plt.figure(figsize=(15,6))
plt.cla()
env.render_all()
plt.show()
